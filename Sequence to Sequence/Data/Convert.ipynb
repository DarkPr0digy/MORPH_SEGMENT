# %%
file = open('ndebele/ndebele.clean.test.conll').read().split('\n')

# %%
output = open('ndebele-words-target.txt', 'w')

for line in file:
    line = line.split(' | ')
    print(line[1])
    outString = line[0].lower() +' '+line[1].lower()+'\n'
    #outString = line[0].lower() +'\n'
    output.write(outString)
# Out:
# li-fuman-e
# e-o-fis-ini
# e-liseduz-e
# ku-fanel-e
# li-zal-is-w-e
# i-nga-s-i
# omu-nye
# u-mu-ntu
# njalo
# si-ba-w-a
# u-fund-e
# u-m-hlahlandlela
# ya-kho
# ye-layisense
# E-si-gabe-ni
# w-e-klayenti
# qal-a
# i-bhokisana
# l-oM-enzi
# w-e-agoa
# nga-pha-si
# E-si-gabe-ni
# se-Mi-niningw-ana
# y-oM-enzi
# w-e-agoa
# vez-a
# i-gama
# lo-kw-enz-a
# i-bhizinisi
# le-bhizinisi
# ya-kho
# i-ndawo
# lapho
# ku-thol-akal-a
# i-bhizinisi
# i-si-bonelo
# i-plodo
# i-gama
# l-estrad-a
# ne-n-omboro
# ye-bhizinisi
# i-sabhabhu
# lapho
# i-bhizinisi
# li-thol-akal-a
# kho-na
# i-dorobha
# eli-khulu
# i-dorobha
# lapho
# i-bhizinisi
# li-thol-akal-a
# kho-na
# ka-nye
# ne-khodi
# y-e-strada
# lapho
# i-bhizinisi
# li-thol-akal-a
# kho-na
# i-si-gaba
# lo-kw-enz-a
# ku-fanel-e
# si-zal-is-w-e
# ku-phel-a
# o-pheth-e
# i-bhizinisi
# lokha
# na-kenz-a
# s-o-kutloliswa
# njengo-m-enzi
# w-e-pahla
# w-e-agoa
# I-gama
# i-gama
# lo-ku-tloliswa
# kwe-gama
# l-e-hlangano
# i-nga-s-i
# i-gama
# ...
